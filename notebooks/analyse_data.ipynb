# %%
import pandas as pd
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("data/data.csv")
df
# Out:
#        n_parties  n_inds  n_large_parties  perc_large_votes
# 0             34       7                2          0.983816
# 1             45       4                6          0.869546
# 2             35       3                2          0.986602
# 3             39       9                0               NaN
# 4             40       6                1          0.858586
# ...          ...     ...              ...               ...
# 24995         46       2                7          0.826730
# 24996         43      11                4          0.849954
# 24997         36       6                2          0.817956
# 24998         45       2                0               NaN
# 24999         31       4                1          0.777790
#
# [25000 rows x 4 columns]

# %%
sns.kdeplot(df, x="n_parties")
# Out:
# <Axes: xlabel='n_parties', ylabel='Density'>

# %%
sns.histplot(df, x="n_inds", bins=20)
# Out:
# <Axes: xlabel='n_inds', ylabel='Count'>

# %%
df.describe()
# Out:
#           n_parties        n_inds  n_large_parties  perc_large_votes
# count  25000.000000  25000.000000     25000.000000      23767.000000
# mean      39.992440      5.008440         3.018040          0.861479
# std        6.312563      2.003369         1.742595          0.078819
# min       18.000000      1.000000         0.000000          0.468823
# 25%       36.000000      4.000000         2.000000          0.809441
# 50%       40.000000      5.000000         3.000000          0.870583
# 75%       44.000000      6.000000         4.000000          0.923674
# max       73.000000     14.000000        14.000000          0.989967
